# %%
import pandas as pd
import numpy as np 
import seaborn as sns

# %%
car_df = pd.read_csv('/aiffel/data/cars.csv')
brand_df = pd.read_csv('/aiffel/data/brand.csv')
car_df.head()
# Out:
#             title  Price  Mileage(miles)  Registration_Year  Previous Owners  \
# 0     SKODA FABIA   6900           70189               2016              3.0
# 1  VAUXHALL CORSA   1495           88585               2008              4.0
# 2     HYUNDAI I30    949          137000               2011              NaN
# 3      MINI HATCH   2395           96731               2010              5.0
# 4  VAUXHALL CORSA   1000           85000               2013              NaN
#
#   Fuel type  Body type Engine Gearbox  Doors  Seats Emission Class  \
# 0    Diesel  Hatchback   1.4L  Manual    5.0    5.0         Euro 6
# 1    Petrol  Hatchback   1.2L  Manual    3.0    5.0         Euro 4
# 2    Petrol  Hatchback   1.4L  Manual    5.0    5.0         Euro 5
# 3    Petrol  Hatchback   1.4L  Manual    3.0    4.0         Euro 4
# 4    Diesel  Hatchback   1.3L  Manual    5.0    5.0         Euro 5
#
#   Service history
# 0             NaN
# 1            Full
# 2             NaN
# 3            Full
# 4             NaN

# %%
brand_df.head()
# Out:
#       title         country
# 0     skoda  Czech Republic
# 1  vauxhall  United Kingdom
# 2   hyundai     South Korea
# 3      mini  United Kingdom
# 4      ford   United States

# %%
brand_df['title'] = brand_df['title'].replace({'skoda': 'SKODA FABIA',
    'vauxhall': 'VAUXHALL CORSA',
    'hyundai': 'HYUNDAI I30',
    'mini': 'MINI HATCH'
})

# %%
print(brand_df.head())
# Out:
#             title         country
# 0     SKODA FABIA  Czech Republic
# 1  VAUXHALL CORSA  United Kingdom
# 2     HYUNDAI I30     South Korea
# 3      MINI HATCH  United Kingdom
# 4            ford   United States

# %%
print(car_df.columns)
print(brand_df.columns)
# Out:
# Index(['title', 'Price', 'Mileage(miles)', 'Registration_Year',
#        'Previous Owners', 'Fuel type', 'Body type', 'Engine', 'Gearbox',
#        'Doors', 'Seats', 'Emission Class', 'Service history'],
#       dtype='object')
# Index(['title', 'country'], dtype='object')

# %%
merge_df = car_df.merge(brand_df, on = 'title', how = 'left')

# %%
print(merge_df.head())
# Out:
#             title  Price  Mileage(miles)  Registration_Year  Previous Owners  \
# 0     SKODA FABIA   6900           70189               2016              3.0
# 1  VAUXHALL CORSA   1495           88585               2008              4.0
# 2     HYUNDAI I30    949          137000               2011              NaN
# 3      MINI HATCH   2395           96731               2010              5.0
# 4  VAUXHALL CORSA   1000           85000               2013              NaN
#
#   Fuel type  Body type Engine Gearbox  Doors  Seats Emission Class  \
# 0    Diesel  Hatchback   1.4L  Manual    5.0    5.0         Euro 6
# 1    Petrol  Hatchback   1.2L  Manual    3.0    5.0         Euro 4
# 2    Petrol  Hatchback   1.4L  Manual    5.0    5.0         Euro 5
# 3    Petrol  Hatchback   1.4L  Manual    3.0    4.0         Euro 4
# 4    Diesel  Hatchback   1.3L  Manual    5.0    5.0         Euro 5
#
#   Service history         country
# 0             NaN  Czech Republic
# 1            Full  United Kingdom
# 2             NaN     South Korea
# 3            Full  United Kingdom
# 4             NaN  United Kingdom

# %%
#카테고리형 변수를 숫자 형태로 변환한다. 
from sklearn.preprocessing import LabelEncoder
# 카테고리형 변수 추출
categorical_columns = merge_df.select_dtypes(include=['object', 'category']).columns.tolist()

# %%
for col in categorical_columns:
    print(f"{col} : {merge_df[col].unique()}")
# Out:
# title : ['SKODA FABIA' 'VAUXHALL CORSA' 'HYUNDAI I30' 'MINI HATCH' 'HYUNDAI COUPE'
#  'FORD FOCUS' 'VOLVO 740' 'PEUGEOT 207' 'FORD FIESTA' 'VAUXHALL INSIGNIA'
#  'BMW 3 SERIES' 'CITROEN C1' 'CITROEN C4' 'VAUXHALL ASTRA' 'FORD MONDEO'
#  'MERCEDES-BENZ A180' 'PEUGEOT 407' 'FORD KA' 'MERCEDES-BENZ A CLASS'
#  'MAZDA MAZDA2' 'SAAB 9-3' 'VOLKSWAGEN POLO' 'BMW 1 SERIES' 'HONDA ACCORD'
#  'VOLKSWAGEN BEETLE' 'MG MG6' 'FORD C-MAX' 'HONDA CIVIC' 'TOYOTA AURIS'
#  'VOLVO S40' 'SEAT IBIZA' 'PEUGEOT 308' 'VAUXHALL MERIVA'
#  'MERCEDES-BENZ B CLASS' 'MAZDA MAZDA3' 'NISSAN 350 Z' 'ALFA ROMEO MITO'
#  'RENAULT FLUENCE' 'VOLKSWAGEN PASSAT' 'KIA SPORTAGE' 'CITROEN XM'
#  'VAUXHALL ANTARA' 'NISSAN NOTE' 'BMW 5 SERIES' 'HONDA CR-V'
#  'PROTON SAVVY' 'NISSAN MICRA' 'FIAT PANDA' 'RENAULT MEGANE'
#  'RENAULT CLIO' 'HYUNDAI I20' 'CITROEN C3' 'AUDI A6 SALOON' 'TOYOTA YARIS'
#  'FIAT 500' 'MERCEDES-BENZ M CLASS' 'AUDI A4' 'PEUGEOT 308 SW'
#  'FORD S-MAX' 'PEUGEOT 1007' 'HONDA ODYSSEY' 'PEUGEOT 307 CC' 'HONDA JAZZ'
#  'MERCEDES-BENZ CLK' 'CITROEN DS4' 'KIA RIO' 'VOLKSWAGEN GOLF'
#  'MITSUBISHI OUTLANDER' 'VOLKSWAGEN SCIROCCO' 'TOYOTA COROLLA' 'AUDI A3'
#  'CITROEN DS3' 'VAUXHALL ZAFIRA' 'FIAT GRANDE PUNTO' 'PEUGEOT 508'
#  'MERCEDES-BENZ 260' 'MG MIDGET' 'VAUXHALL ADAM' 'AUDI A6 AVANT'
#  'NISSAN QASHQAI' 'NISSAN ALMERA TINO' 'MERCEDES-BENZ C CLASS'
#  'TOYOTA AVENSIS' 'RENAULT GRAND SCENIC' 'MAZDA MAZDA 2'
#  'VOLKSWAGEN TOURAN' 'MITSUBISHI ASX' 'LEXUS GS 300'
#  'LAND ROVER FREELANDER' 'PEUGEOT 307' 'FIAT PUNTO EVO' 'NISSAN ALMERA'
#  'LEXUS IS 250' 'CHEVROLET CRUZE' 'HYUNDAI VELOSTER' 'FORD FUSION'
#  'VAUXHALL VECTRA' 'BMW 7 SERIES' 'PEUGEOT 208' 'SUZUKI GRAND VITARA'
#  'PEUGEOT 2008' 'PEUGEOT 107' 'RENAULT SCENIC' 'VOLVO V50'
#  'MITSUBISHI COLT' 'HYUNDAI IX35' 'HYUNDAI IX20' 'FIAT DOBLO'
#  'FORD MUSTANG' 'SKODA OCTAVIA' 'DACIA SANDERO' 'DAIHATSU TERIOS'
#  'ALFA ROMEO GIULIETTA' 'FIAT PUNTO' 'CITROEN C3 PICASSO'
#  'CHEVROLET MATIZ' 'JEEP COMPASS' 'VAUXHALL TIGRA' 'JAGUAR XE'
#  'CHRYSLER SEBRING' 'NISSAN X-TRAIL' 'PEUGEOT 108' 'PEUGEOT 207 SW'
#  'BMW X3' 'ALFA ROMEO 159' 'KIA CEED' 'JAGUAR X-TYPE' 'SUZUKI JIMNY'
#  'NISSAN LAFESTA' 'VOLVO C30' 'TOYOTA VERSO' 'MERCEDES-BENZ E CLASS'
#  'PEUGEOT 206' 'CHEVROLET CAPTIVA' 'TOYOTA RAV4' 'HONDA FR-V'
#  'MERCEDES-BENZ CLS' 'TOYOTA AYGO' 'LAND ROVER RANGE ROVER EVOQUE'
#  'ROVER 75' 'PEUGEOT 5008' 'MERCEDES-BENZ C-CLASS' 'RENAULT LAGUNA'
#  'NISSAN QASHQAI+2' 'JAGUAR XF' 'MERCEDES-BENZ SLK' 'AUDI A5'
#  'ALFA ROMEO GT' 'TOYOTA COROLLA VERSO' 'PEUGEOT PARTNER TEPEE'
#  'PEUGEOT 3008' 'FIAT 500C' 'ROVER MINI' 'VAUXHALL MOKKA'
#  'CITROEN GRAND C4 PICASSO' 'VOLKSWAGEN JETTA' 'BMW X5'
#  'VAUXHALL ASTRA GTC' 'LAND ROVER RANGE ROVER SPORT' 'FORD GRAND C-MAX'
#  'TOYOTA PRIUS' 'VOLKSWAGEN TIGUAN' 'MITSUBISHI FTO'
#  'LAND ROVER RANGE ROVER' 'BMW Z4' 'SUZUKI SWIFT' 'TOYOTA CAMRY'
#  'LEXUS LS 430' 'CITROEN C4 CACTUS' 'DS AUTOMOBILES DS 3' 'KIA PICANTO'
#  'VOLVO S80' 'SUZUKI SX4 S-CROSS' 'DAEWOO KALOS' 'VOLKSWAGEN EOS'
#  'SUZUKI ALTO' 'CHEVROLET AVEO' 'DODGE NITRO' 'TOYOTA MARK X'
#  'NISSAN JUKE' 'MAZDA MAZDA6' 'NISSAN CUBIC' 'KIA SOUL' 'BMW X1'
#  'NISSAN PATHFINDER' 'VOLKSWAGEN GOLF PLUS' 'MAZDA CX-5'
#  'MINI CONVERTIBLE' 'CHRYSLER 300C' 'HONDA FREED' 'HONDA LEGEND'
#  'NISSAN ELGRAND' 'SKODA SUPERB' 'SKODA RAPID SPACEBACK'
#  'CHRYSLER YPSILON' 'SAAB 900' 'FORD B-MAX' 'CHEVROLET SPARK'
#  'PEUGEOT 306' 'VOLKSWAGEN PHAETON' 'LEXUS CT 200H' 'AUDI A1'
#  'NISSAN MURANO' 'PEUGEOT 406' 'MG MG3' 'JEEP RENEGADE' 'FIAT 500L'
#  'CHRYSLER GRAND VOYAGER' 'BMW 4 SERIES' 'RENAULT CAPTUR' 'PORSCHE 944'
#  'FORD GALAXY' 'HYUNDAI ACCENT' 'VOLVO S60' 'NISSAN SUNNY'
#  'SUBARU IMPREZA' 'VOLKSWAGEN BORA' 'NISSAN PRIMERA' 'VOLVO V70'
#  'PORSCHE CAYENNE' 'RENAULT KANGOO' 'SEAT ALTEA' 'SKODA RAPID'
#  'LAND ROVER FREELANDER 2' 'HYUNDAI GETZ' 'CITROEN BX' 'TOYOTA IQ'
#  'SUZUKI LIANA' 'MITSUBISHI SHOGUN SPORT' 'INFINITI Q30'
#  'MERCEDES-BENZ S CLASS' 'HYUNDAI I10' 'AUDI TT' 'MAZDA 3' 'FORD KUGA'
#  'BMW ALPINA D3' 'RENAULT TWINGO' 'FIAT 500X' 'VOLVO V60'
#  'MERCEDES-BENZ SL CLASS' 'HYUNDAI I40' 'MAZDA RX-8'
#  'CITROEN XSARA PICASSO' 'INFINITI G' 'VOLVO V40' 'SUBARU OUTBACK'
#  'SEAT LEON' 'PEUGEOT RCZ' 'INFINITI M' 'HYUNDAI TUCSON'
#  'VAUXHALL ZAFIRA TOURER' 'SKODA ROOMSTER' 'ABARTH 500' 'SUZUKI SPLASH'
#  'CITROEN BERLINGO' 'AUDI A4 AVANT' 'SUZUKI SX4' 'VOLKSWAGEN CC'
#  'SMART FORTWO' 'DACIA SANDERO STEPWAY' 'MITSUBISHI SHOGUN'
#  'AUDI A3 CABRIOLET' 'BMW 2 SERIES' 'MAZDA MX-5' 'MINI HATCH ONE'
#  'HONDA CR-Z' 'MINI COUNTRYMAN' 'RENAULT GRAND ESPACE' 'JAGUAR S-TYPE'
#  'DACIA LOGAN MCV' 'VAUXHALL INSIGNIA GRAND SPORT' 'MERCEDES-BENZ B-CLASS'
#  'KIA OPTIMA' 'KIA SORENTO' 'PEUGEOT 207 CC' 'MAZDA CX-3' 'AUDI Q7'
#  'MINI CLUBMAN' 'JAGUAR XJ' 'VAUXHALL GRANDLAND X' 'FORD FOCUS CC'
#  'SMART FORFOUR' 'JEEP GRAND CHEROKEE' 'AUDI A6' 'MITSUBISHI LANCER'
#  'MG ZT' 'BMW X6' 'PROTON PROTON' 'VOLKSWAGEN POLO HATCHBACK'
#  'ABARTH FIAT 595 1.4 TJET (165PS) SCORPIONEORO' 'MINI HATCH COOPER'
#  'BMW 4 SERIES GRAN COUPE' 'KIA STONIC' 'TOYOTA PRIUS+' 'KIA PROCEED'
#  'DS AUTOMOBILES DS 7 CROSSBACK' 'FORD ECOSPORT' 'CITROEN C4 PICASSO'
#  'MERCEDES-BENZ S-CLASS' 'DS AUTOMOBILES DS 9' 'LEXUS SC 430'
#  'MAZDA MX-30' 'MERCEDES-BENZ CL' 'SUBARU XV' 'AUDI Q3' 'HYUNDAI SANTA FE'
#  'PEUGEOT 508 SW' 'SKODA CITIGO' 'AUDI A5 DIESEL COUPE' 'NISSAN LEAF'
#  'NISSAN QASHQAI HATCHBACK SPECIAL EDITIONS' 'AUDI A4 CABRIOLET'
#  'VOLKSWAGEN SHARAN' 'SKODA YETI' 'TOYOTA URBANCRUISER'
#  'SKODA FABIA DIESEL ESTATE' 'KIA VENGA' 'CITROEN DS3 CABRIO'
#  'MARCOS MARTINA' 'HYUNDAI KONA' 'SUZUKI SWIFT HATCHBACK'
#  'VOLKSWAGEN T-CROSS' 'VAUXHALL CORSA HATCHBACK' 'VAUXHALL VIVA HATCHBACK'
#  'MASERATI GRANTURISMO' 'AUDI A5 CABRIOLET' 'SEAT TARRACO'
#  'VAUXHALL COMBO' 'VAUXHALL AGILA' 'MERCEDES-BENZ A-CLASS' 'INFINITI FX'
#  'PEUGEOT 308 CC' 'VOLVO XC90'
#  'LAND ROVER RANGE ROVER EVOQUE DIESEL HATCHBACK'
#  'FORD FOCUS DIESEL HATCHBACK' 'CITROEN C3 AIRCROSS DIESEL MPV'
#  'MITSUBISHI GTO' 'MINI PACEMAN' 'VAUXHALL CROSSLAND X'
#  'FORD KUGA DIESEL HATCHBACK' 'KIA SPORTAGE DIESEL ESTATE'
#  'MERCEDES-BENZ CLA CLASS' 'INFINITI EX' 'RENAULT MEGANE HATCH'
#  'NISSAN X-TRAIL DIESEL ESTATE' 'NISSAN QASHQAI DIESEL HATCHBACK'
#  'KIA CEED DIESEL HATCHBACK' 'JAGUAR XE DIESEL SALOON' 'MASERATI GHIBLI'
#  'FORD FOCUS HATCHBACK' 'NISSAN PULSAR' 'FORD FIESTA HATCHBACK'
#  'MERCEDES-BENZ E CLASS DIESEL COUPE' 'CITROEN C6' 'CITROEN C3 AIRCROSS'
#  'SUZUKI VITARA' 'MITSUBISHI L200' 'SKODA KAMIQ'
#  'VAUXHALL CORSA HATCHBACK SPECIAL EDS' 'HONDA JAZZ HATCHBACK'
#  'MERCEDES-BENZ E CLASS DIESEL ESTATE' 'VOLKSWAGEN JETTA DIESEL SALOON'
#  'HYUNDAI I20 HATCHBACK' 'MINI COUPE' 'MERCEDES-BENZ GLA CLASS'
#  'NISSAN NAVARA DIESEL PICK UP' 'MAZDA 2' 'MG MG HS' 'HONDA FIT'
#  'MINI HATCHBACK' 'SKODA KAROQ ESTATE' 'BMW 3 SERIES GRAN TURISMO'
#  'FORD KA+' 'BMW 5 SERIES GRAN TURISMO' 'HYUNDAI IONIQ' 'CHEVROLET TRAX'
#  'RENAULT MODUS' 'VAUXHALL INSIGNIA SPORTS TOURER' 'FORD KUGA ESTATE'
#  'SUZUKI IGNIS' 'SSANGYONG KORANDO' 'DACIA DUSTER' 'VAUXHALL MOKKA X'
#  'HONDA CIVIC DIESEL HATCHBACK' 'NISSAN QASHQAI HATCHBACK'
#  'CITROEN C4 PICASSO DIESEL MPV' 'FORD FOCUS ACTIVE' 'RENAULT ARKANA'
#  'VOLKSWAGEN SCIROCCO DIESEL COUPE' 'LAND ROVER DISCOVERY SPORT'
#  'VOLVO C70' 'MAZDA MAZDA3 HATCHBACK' 'VOLKSWAGEN GOLF HATCHBACK'
#  'VAUXHALL CROSSLAND' 'VOLKSWAGEN PASSAT PETROL/ELECTRIC SALOON'
#  'PEUGEOT 2008 ESTATE' 'LAGONDA LG6 ROADSTER' 'VOLKSWAGEN UP!'
#  'VAUXHALL AMPERA' 'VOLKSWAGEN UP' 'MASERATI QUATTROPORTE'
#  'FORD ECOSPORT HATCHBACK' 'SUBARU FORESTER' 'AUDI A3 HATCHBACK'
#  'KIA XCEED' 'DS AUTOMOBILES DS 3 CROSSBACK' 'AUDI Q5' 'INFINITI Q50'
#  'FIAT FULLBACK' 'AUDI S3' 'AUDI A1 SPORTBACK' 'MG MG ZS' 'SEAT ATECA'
#  'MERCEDES-BENZ A CLASS DIESEL HATCHBACK' 'AUDI A7' 'ABARTH 595'
#  'RENAULT KOLEOS' 'PEUGEOT 208 PURETECH ACTIVE PREMIUM S/S HATCHBACK'
#  'DACIA DUSTER ESTATE' 'VOLKSWAGEN GOLF DIESEL HATCHBACK'
#  'LAND ROVER DISCOVERY 4' 'AUDI Q2 ESTATE'
#  'BMW 2 SERIES DIESEL GRAN TOURER' 'VAUXHALL CROSSLAND X HATCHBACK'
#  'MERCEDES-BENZ GLE CLASS' 'MAZDA MAZDA6 TOURER' 'KIA SPORTAGE ESTATE'
#  'BMW X3 SERIES' 'VOLKSWAGEN CADDY MAXI LIFE' 'KIA XCEED HATCHBACK'
#  'FIAT STILO' 'AUDI A6 ALLROAD' 'SEAT TOLEDO' 'FORD STREETKA'
#  'JEEP PATRIOT' 'MG TF' 'MG ZR' 'FIAT MULTIPLA' 'VOLKSWAGEN LUPO'
#  'PEUGEOT 206 CC' 'CHRYSLER PT CRUISER' 'FORD FOCUS C-MAX' 'ROVER 45'
#  'LEXUS GS 450H' 'TOYOTA CARINA' 'CITROEN C5' 'HYUNDAI AMICA'
#  'ALFA ROMEO BRERA' 'VAUXHALL VIVARO' 'PEUGEOT 607' 'ISUZU TROOPER'
#  'FIAT IDEA' 'ROVER 800' 'JEEP CHEROKEE' 'HONDA PRELUDE']
# Fuel type : ['Diesel' 'Petrol' 'Petrol Plug-in Hybrid' 'Petrol Hybrid' 'Electric'
#  'Diesel Hybrid']
# Body type : ['Hatchback' 'Coupe' 'Estate' 'Saloon' 'Convertible' 'MPV' 'SUV' 'Minibus'
#  'Combi Van' 'Pickup']
# Engine : ['1.4L' '1.2L' '1.3L' '2.0L' '1.6L' '2.3L' '1.8L' '1.0L' '3.0L' '1.5L'
#  '1.9L' '2.4L' '2.2L' '3.5L' '3.2L' '2.5L' '1.1L' '3.1L' '3.7L' '2.6L'
#  '2.1L' '2.8L' '5.0L' '0.8L' '2.7L' '1.7L' '0.9L' '4.2L' nan '4.4L' '4.3L'
#  '3.3L' '5.5L' '4.8L' '6.3L']
# Gearbox : ['Manual' 'Automatic']
# Emission Class : ['Euro 6' 'Euro 4' 'Euro 5' nan 'Euro 3' 'Euro 2' 'Euro 1']
# Service history : [nan 'Full']
# country : ['Czech Republic' 'United Kingdom' 'South Korea' nan]

# %%
#service_history NaN => unknown value
isnull_df = merge_df.isnull()
missing_sum = isnull_df.sum()
missing_filtered = missing_sum[missing_sum > 0]
print(missing_filtered)
# Out:
# Previous Owners    1411
# Engine               45
# Doors                25
# Seats                35
# Emission Class       87
# Service history    3147
# country            3325
# dtype: int64

# %%
#결측치를 각 컬럼의 특성에 맞춰서 처리해본다. 
# service history _ NaN -> Unknown
merge_df['Service history'] = merge_df['Service history'].fillna('unknown')
print(merge_df['Service history'].isnull().sum())
# Out:
# 0

# %%
#missing_filtered에 결측치를 제거한 service history컬럼을 업데이트해줘야한다 
missing_filtered = merge_df.isnull().sum()
missing_filtered = missing_filtered[missing_filtered > 0]
print(missing_filtered)
# Out:
# Previous Owners    1411
# Engine               45
# Doors                25
# Seats                35
# Emission Class       87
# country            3325
# dtype: int64

# %%
#결측치 제거 이후에 
# 결측치가 1000개 이상인 데이터를 지운다. 
columns_to_drop = missing_filtered[missing_filtered >= 1000].index.tolist()

# %%
#국가별 총 브랜드 수는?
# 결측치 1000 이상인 데이터 삭제중에 컨트리를 제외하자.

# %%
columns_to_drop = [col for col in columns_to_drop if col != 'country']

# %%
cleaned_df = merge_df.drop(columns = columns_to_drop)

# %%
print(columns_to_drop)
# Out:
# ['Previous Owners']

# %%
cleaned_df[cleaned_df['country'].notnull()]
# Out:
#                title  Price  Mileage(miles)  Registration_Year Fuel type  \
# 0        SKODA FABIA   6900           70189               2016    Diesel
# 1     VAUXHALL CORSA   1495           88585               2008    Petrol
# 2        HYUNDAI I30    949          137000               2011    Petrol
# 3         MINI HATCH   2395           96731               2010    Petrol
# 4     VAUXHALL CORSA   1000           85000               2013    Diesel
# ...              ...    ...             ...                ...       ...
# 3650      MINI HATCH  11999           33156               2018    Petrol
# 3653  VAUXHALL CORSA   1850           88000               2009    Petrol
# 3656  VAUXHALL CORSA   1995          126000               2013    Diesel
# 3662      MINI HATCH  11999           33156               2018    Petrol
# 3686  VAUXHALL CORSA   2000           82160               2013    Petrol
#
#       Body type Engine Gearbox  Doors  Seats Emission Class Service history  \
# 0     Hatchback   1.4L  Manual    5.0    5.0         Euro 6         unknown
# 1     Hatchback   1.2L  Manual    3.0    5.0         Euro 4            Full
# 2     Hatchback   1.4L  Manual    5.0    5.0         Euro 5         unknown
# 3     Hatchback   1.4L  Manual    3.0    4.0         Euro 4            Full
# 4     Hatchback   1.3L  Manual    5.0    5.0         Euro 5         unknown
# ...         ...    ...     ...    ...    ...            ...             ...
# 3650  Hatchback   1.5L  Manual    5.0    5.0         Euro 6            Full
# 3653  Hatchback   1.2L  Manual    3.0    5.0         Euro 4         unknown
# 3656  Hatchback   1.3L  Manual    5.0    5.0         Euro 5         unknown
# 3662  Hatchback   1.5L  Manual    5.0    5.0         Euro 6            Full
# 3686  Hatchback   1.2L  Manual    5.0    5.0         Euro 5         unknown
#
#              country
# 0     Czech Republic
# 1     United Kingdom
# 2        South Korea
# 3     United Kingdom
# 4     United Kingdom
# ...              ...
# 3650  United Kingdom
# 3653  United Kingdom
# 3656  United Kingdom
# 3662  United Kingdom
# 3686  United Kingdom
#
# [362 rows x 13 columns]

# %%
# country_brand_sum()구하기 
brand_by_country = cleaned_df.groupby('country')['title'].count().sort_values(ascending=False)

# %%
#Scaler활용하기 : 모델이 여러 특성(features_)을 사용할 때, 값이 크기가 너무 다르면 특정 특성이 더 큰 영향력을 갖는다. 학습을 왜곡시키고 성능을 저조하게 함. 
from sklearn.preprocessing import StandardScaler

# %%
# one-Hot Encoding 범주형 변수를 0과 1ㅡ의 조합으로 바꾸는 방식이다. 
# 가장 효과적인 특정 컬럼만 축출해서 생성해보자. 
# 범주 간 순서가 없음.범주의 개수가 너무 많지 않음. 머신러닝 모델이 선형 회귀나 로지스틱 회귀일 경우 / 숫자간 간격을 의미로 받아들이기 때문에 원스팟이 필수이다.

# %%
# Emission Class로 해본다. 
# 범주 수가 많으면 Label Encoding 고려할 수 있다. Gearbox 두가지 명확하여 이게 더 나아보인다.

# %%
encode_targets = ['Gearbox', 'Emission Class']
encode_df = pd.get_dummies(merge_df, columns=encode_targets)

# %%
for col in encode_df.columns:
    if 'Gearbox' in col or 'Emission Class' in col:
        print(col)
# Out:
# Gearbox_Automatic
# Gearbox_Manual
# Emission Class_Euro 1
# Emission Class_Euro 2
# Emission Class_Euro 3
# Emission Class_Euro 4
# Emission Class_Euro 5
# Emission Class_Euro 6

# %%
encode_df.head()
# Out:
#             title  Price  Mileage(miles)  Registration_Year  Previous Owners  \
# 0     SKODA FABIA   6900           70189               2016              3.0
# 1  VAUXHALL CORSA   1495           88585               2008              4.0
# 2     HYUNDAI I30    949          137000               2011              NaN
# 3      MINI HATCH   2395           96731               2010              5.0
# 4  VAUXHALL CORSA   1000           85000               2013              NaN
#
#   Fuel type  Body type Engine  Doors  Seats Service history         country  \
# 0    Diesel  Hatchback   1.4L    5.0    5.0         unknown  Czech Republic
# 1    Petrol  Hatchback   1.2L    3.0    5.0            Full  United Kingdom
# 2    Petrol  Hatchback   1.4L    5.0    5.0         unknown     South Korea
# 3    Petrol  Hatchback   1.4L    3.0    4.0            Full  United Kingdom
# 4    Diesel  Hatchback   1.3L    5.0    5.0         unknown  United Kingdom
#
#    Gearbox_Automatic  Gearbox_Manual  Emission Class_Euro 1  \
# 0                  0               1                      0
# 1                  0               1                      0
# 2                  0               1                      0
# 3                  0               1                      0
# 4                  0               1                      0
#
#    Emission Class_Euro 2  Emission Class_Euro 3  Emission Class_Euro 4  \
# 0                      0                      0                      0
# 1                      0                      0                      1
# 2                      0                      0                      0
# 3                      0                      0                      1
# 4                      0                      0                      0
#
#    Emission Class_Euro 5  Emission Class_Euro 6
# 0                      0                      1
# 1                      0                      0
# 2                      1                      0
# 3                      0                      0
# 4                      1                      0

# %%
print(encode_df[encode_df['Gearbox_Manual'] == 1].shape)
# Out:
# (2870, 20)

# %%
print([col for col in encode_df.columns if 'Emission Class' in col or 'Gearbox_Manual' in col])
# Out:
# ['Gearbox_Manual', 'Emission Class_Euro 1', 'Emission Class_Euro 2', 'Emission Class_Euro 3', 'Emission Class_Euro 4', 'Emission Class_Euro 5', 'Emission Class_Euro 6']

# %%
#one top encoding이후 절차 
# EDA 분석 
# 통계요약 , 결측치 확인, 범주의 시각화, PCA등

# %%
encode_df.describe()
# Out:
#               Price  Mileage(miles)  Registration_Year  Previous Owners  \
# count   3687.000000    3.687000e+03        3687.000000      2276.000000
# mean    5787.301058    8.132854e+04        2011.846216         2.807557
# std     4480.629885    3.941718e+04           5.082387         1.546028
# min      400.000000    1.000000e+00        1953.000000         1.000000
# 25%     2490.000000    5.698400e+04        2008.000000         2.000000
# 50%     4000.000000    8.000000e+04        2012.000000         3.000000
# 75%     7995.000000    1.030000e+05        2015.500000         4.000000
# max    33900.000000    1.110100e+06        2025.000000         9.000000
#
#              Doors        Seats  Gearbox_Automatic  Gearbox_Manual  \
# count  3662.000000  3652.000000        3687.000000     3687.000000
# mean      4.321409     4.900329           0.221589        0.778411
# std       0.986760     0.577046           0.415373        0.415373
# min       2.000000     2.000000           0.000000        0.000000
# 25%       3.000000     5.000000           0.000000        1.000000
# 50%       5.000000     5.000000           0.000000        1.000000
# 75%       5.000000     5.000000           0.000000        1.000000
# max       5.000000     7.000000           1.000000        1.000000
#
#        Emission Class_Euro 1  Emission Class_Euro 2  Emission Class_Euro 3  \
# count            3687.000000            3687.000000            3687.000000
# mean                0.001085               0.006781               0.037158
# std                 0.032924               0.082076               0.189173
# min                 0.000000               0.000000               0.000000
# 25%                 0.000000               0.000000               0.000000
# 50%                 0.000000               0.000000               0.000000
# 75%                 0.000000               0.000000               0.000000
# max                 1.000000               1.000000               1.000000
#
#        Emission Class_Euro 4  Emission Class_Euro 5  Emission Class_Euro 6
# count            3687.000000            3687.000000            3687.000000
# mean                0.289666               0.340928               0.300787
# std                 0.453669               0.474085               0.458662
# min                 0.000000               0.000000               0.000000
# 25%                 0.000000               0.000000               0.000000
# 50%                 0.000000               0.000000               0.000000
# 75%                 1.000000               1.000000               1.000000
# max                 1.000000               1.000000               1.000000

# %%
# 수치형의 컬럼을 축출하고 결측치를 제거한다 
numeric_df = encode_df.select_dtypes(include=['number'])
clean_numeric_df = numeric_df.dropna(axis = 1)
clean_numeric_df.describe()
# Out:
#               Price  Mileage(miles)  Registration_Year  Gearbox_Automatic  \
# count   3687.000000    3.687000e+03        3687.000000        3687.000000
# mean    5787.301058    8.132854e+04        2011.846216           0.221589
# std     4480.629885    3.941718e+04           5.082387           0.415373
# min      400.000000    1.000000e+00        1953.000000           0.000000
# 25%     2490.000000    5.698400e+04        2008.000000           0.000000
# 50%     4000.000000    8.000000e+04        2012.000000           0.000000
# 75%     7995.000000    1.030000e+05        2015.500000           0.000000
# max    33900.000000    1.110100e+06        2025.000000           1.000000
#
#        Gearbox_Manual  Emission Class_Euro 1  Emission Class_Euro 2  \
# count     3687.000000            3687.000000            3687.000000
# mean         0.778411               0.001085               0.006781
# std          0.415373               0.032924               0.082076
# min          0.000000               0.000000               0.000000
# 25%          1.000000               0.000000               0.000000
# 50%          1.000000               0.000000               0.000000
# 75%          1.000000               0.000000               0.000000
# max          1.000000               1.000000               1.000000
#
#        Emission Class_Euro 3  Emission Class_Euro 4  Emission Class_Euro 5  \
# count            3687.000000            3687.000000            3687.000000
# mean                0.037158               0.289666               0.340928
# std                 0.189173               0.453669               0.474085
# min                 0.000000               0.000000               0.000000
# 25%                 0.000000               0.000000               0.000000
# 50%                 0.000000               0.000000               0.000000
# 75%                 0.000000               1.000000               1.000000
# max                 1.000000               1.000000               1.000000
#
#        Emission Class_Euro 6
# count            3687.000000
# mean                0.300787
# std                 0.458662
# min                 0.000000
# 25%                 0.000000
# 50%                 0.000000
# 75%                 1.000000
# max                 1.000000

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
scaled_data = scaler.fit_transform(clean_numeric_df)
scaled_df = pd.DataFrame(scaled_data, columns=clean_numeric_df.columns)

# %%
scaled_df.head()
# Out:
#       Price  Mileage(miles)  Registration_Year  Gearbox_Automatic  \
# 0  0.248369       -0.282644           0.817401          -0.533544
# 1 -0.958098        0.184119          -0.756876          -0.533544
# 2 -1.079973        1.412557          -0.166522          -0.533544
# 3 -0.757206        0.390808          -0.363307          -0.533544
# 4 -1.068589        0.093156           0.227047          -0.533544
#
#    Gearbox_Manual  Emission Class_Euro 1  Emission Class_Euro 2  \
# 0        0.533544              -0.032956              -0.082625
# 1        0.533544              -0.032956              -0.082625
# 2        0.533544              -0.032956              -0.082625
# 3        0.533544              -0.032956              -0.082625
# 4        0.533544              -0.032956              -0.082625
#
#    Emission Class_Euro 3  Emission Class_Euro 4  Emission Class_Euro 5  \
# 0              -0.196447              -0.638584              -0.719225
# 1              -0.196447               1.565965              -0.719225
# 2              -0.196447              -0.638584               1.390386
# 3              -0.196447               1.565965              -0.719225
# 4              -0.196447              -0.638584               1.390386
#
#    Emission Class_Euro 6
# 0               1.524669
# 1              -0.655880
# 2              -0.655880
# 3              -0.655880
# 4              -0.655880

# %%
#PCA principle component analysis: 데이터 분석과 머신러닝에서 매우 자주 사용. 
#차원의 축소 기법 
#공분산행렬 : 두 변수 간의 변동관계

# %%
from sklearn.decomposition import PCA 
import matplotlib.pyplot as plt

# %%
pca = PCA(n_components=0.70)
# pca 객체 생성과 주 성분을 70프로 이상 포함하는 식
pca_result = pca.fit_transform(scaled_df)
# pca learn and transform 
print("selcec components number: ", pca.n_components_)
print(pca_result)
# Out:
# selcec components number:  4
# [[-1.69204351 -0.6584498  -0.64850097  0.32846084]
#  [ 1.665559   -0.71744215 -1.37369149 -0.54002619]
#  [ 1.27628423 -1.06487475  1.66697821 -0.10944175]
#  ...
#  [ 0.75763751 -0.97350478  1.70333413 -0.16728183]
#  [ 2.56954885 -0.5433041  -1.09413328 -0.5759563 ]
#  [ 0.48145924 -1.15159651  1.52553836 -0.13014047]]

# %%
# 상관관계가 높은 변수들이 있는지 확인해본다. 
# dr.corr() 수치형 변수 간의 상관관계
# sns.heatmap() visualization 
# np.where() + .abs() 특정 임계치 이상인 변수 쌍을 찾아냄.

# %%
corr_matrix = scaled_df.corr()
#상관관계의 행렬을 생성한다. 
#시각화
plt.figure(figsize=(15,10))
sns.heatmap(corr_matrix, annot=True, cmap='coolwarm', fmt='.2f')
plt.title("correlation")
plt.show()

# %%
threshold = 0.6
corr_pairs = corr_matrix.abs().unstack().sort_values(ascending=False)
# 상관관계를 쌍으로 펼치고, 0.9 이상치를 정렬한다. 
high_corr = corr_pairs[(corr_pairs < 1.0) & (corr_pairs >= 0.6)]
print(high_corr)
# Out:
# Emission Class_Euro 6  Price                    0.734429
# Price                  Emission Class_Euro 6    0.734429
# Registration_Year      Price                    0.722971
# Price                  Registration_Year        0.722971
# Emission Class_Euro 6  Registration_Year        0.722327
# Registration_Year      Emission Class_Euro 6    0.722327
# dtype: float64
